# %%
import pandas as pd
df = pd.read_parquet('weather_20250529.parquet')

print('Feature columns:', df.columns.tolist())

print('Shape:', df.shape)

print('Sample data:')
print(df)

# %%
import pandas as pd
df = pd.read_parquet('Feature_20250529.parquet')

print('Feature columns:', df.columns.tolist())

print('Shape:', df.shape)

print('Sample data:')
print(df)
